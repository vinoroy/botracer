# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import ipywidgets as wdg  # Using the ipython notebook widgets

# Create a random image
a = np.random.poisson(size=(12,15))
fig = plt.figure()
plt.imshow(a)

# Create and display textarea widget
txt = wdg.Textarea(
    value='',
    placeholder='',
    description='event:',
    disabled=False
)
display(txt)

# Define a callback function that will update the textarea
def onclick(event):
    txt.value = str(event)  # Dynamically update the text box above

# Create an hard reference to the callback not to be cleared by the garbage collector
ka = fig.canvas.mpl_connect('button_press_event', onclick)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Textarea(value='', description='event:', placeholder='')

# %%
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import cv2


import random


from IPython.display import display
import ipywidgets as wdg  # Using the ipython notebook widgets
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-656e892039f6> in <module>
#       4 import matplotlib.image as mpimg
#       5
# ----> 6 import cv2
#       7
#       8
#
# ModuleNotFoundError: No module named 'cv2'

# %%
images = np.load('images.npy')
cats = np.load('cats.npy')

images.shape
# Out:
# (900, 224, 224, 3)

# %%
is_success, im_buf_arr = cv2.imencode(".jpg", images[1])
img = im_buf_arr.tobytes()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-0800e80e8af4> in <module>
# ----> 1 is_success, im_buf_arr = cv2.imencode(".jpg", images[1])
#       2 img = im_buf_arr.tobytes()
#
# NameError: name 'cv2' is not defined

# %%
# create the output widget for text message
output = wdg.Output()


# create the image display widget
imgDisp = wdg.Image(
            value=img,
            format='png',
            width=300,
            height=400,
        )



# display to the screen the widgets
display(output, imgDisp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-27ec0d598018> in <module>
#       5 # create the image display widget
#       6 imgDisp = wdg.Image(
# ----> 7             value=img,
#       8             format='png',
#       9             width=300,
#
# NameError: name 'img' is not defined
